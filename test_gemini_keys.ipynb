# %%
# Import required libraries
import os
from dotenv import load_dotenv
import google.generativeai as genai

# Load environment variables from .env file
load_dotenv(override=True)
print("Environment variables loaded!")
# Out:
# Environment variables loaded!

# %%
import google.generativeai as genai
import os

genai.configure(api_key=os.getenv("GOOGLE_API_KEY_10"))

models = genai.list_models()

for m in models:
    print(m.name, " | supported:", m.supported_generation_methods)
# Out:
# models/gemini-2.5-flash  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-pro  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-001  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite-001  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.0-flash-lite  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-flash-preview-tts  | supported: ['countTokens', 'generateContent']
# models/gemini-2.5-pro-preview-tts  | supported: ['countTokens', 'generateContent', 'batchGenerateContent']
# models/gemma-4-26b-a4b-it  | supported: ['generateContent', 'countTokens']
# models/gemma-4-31b-it  | supported: ['generateContent', 'countTokens']
# models/gemini-flash-latest  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-flash-lite-latest  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-pro-latest  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-flash-lite  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-flash-image  | supported: ['generateContent', 'countTokens', 'batchGenerateContent']
# models/gemini-3-pro-preview  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3-flash-preview  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3.1-pro-preview  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3.1-pro-preview-customtools  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3.1-flash-lite-preview  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3.1-flash-lite  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-3-pro-image-preview  | supported: ['generateContent', 'countTokens', 'batchGenerateContent']
# models/nano-banana-pro-preview  | supported: ['generateContent', 'countTokens', 'batchGenerateContent']
# models/gemini-3.1-flash-image-preview  | supported: ['generateContent', 'countTokens', 'batchGenerateContent']
# models/lyria-3-clip-preview  | supported: ['generateContent', 'countTokens']
# models/lyria-3-pro-preview  | supported: ['generateContent', 'countTokens']
# models/gemini-3.1-flash-tts-preview  | supported: ['generateContent', 'countTokens', 'batchGenerateContent']
# models/gemini-robotics-er-1.5-preview  | supported: ['generateContent', 'countTokens']
# models/gemini-robotics-er-1.6-preview  | supported: ['generateContent', 'countTokens', 'createCachedContent', 'batchGenerateContent']
# models/gemini-2.5-computer-use-preview-10-2025  | supported: ['generateContent', 'countTokens']
# models/deep-research-max-preview-04-2026  | supported: ['generateContent', 'countTokens']
# models/deep-research-preview-04-2026  | supported: ['generateContent', 'countTokens']
# models/deep-research-pro-preview-12-2025  | supported: ['generateContent', 'countTokens']
# models/gemini-embedding-001  | supported: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# models/gemini-embedding-2-preview  | supported: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# models/gemini-embedding-2  | supported: ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# models/aqa  | supported: ['generateAnswer']
# models/imagen-4.0-generate-001  | supported: ['predict']
# models/imagen-4.0-ultra-generate-001  | supported: ['predict']
# models/imagen-4.0-fast-generate-001  | supported: ['predict']
# models/veo-2.0-generate-001  | supported: ['predictLongRunning']
# models/veo-3.0-generate-001  | supported: ['predictLongRunning']
# models/veo-3.0-fast-generate-001  | supported: ['predictLongRunning']
# models/veo-3.1-generate-preview  | supported: ['predictLongRunning']
# models/veo-3.1-fast-generate-preview  | supported: ['predictLongRunning']
# models/veo-3.1-lite-generate-preview  | supported: ['predictLongRunning']
# models/gemini-2.5-flash-native-audio-latest  | supported: ['countTokens', 'bidiGenerateContent']
# models/gemini-2.5-flash-native-audio-preview-09-2025  | supported: ['countTokens', 'bidiGenerateContent']
# models/gemini-2.5-flash-native-audio-preview-12-2025  | supported: ['countTokens', 'bidiGenerateContent']
# models/gemini-3.1-flash-live-preview  | supported: ['bidiGenerateContent']

# %%
def resolve_test_model_name() -> str:
    """Resolve the best Gemma model name available for this API key set.

    Prefers Gemma 4 if present, then falls back to Gemma 3.
    """
    models = list(genai.list_models())
    supported = [
        m.name.replace("models/", "")
        for m in models
        if "generateContent" in (m.supported_generation_methods or [])
    ]

    # Prefer Gemma 4 first (if enabled on the current API project).
    gemma4 = [name for name in supported if "gemma-4" in name.lower()]
    if gemma4:
        chosen = gemma4[0]
        print(f"Using Gemma 4 model: {chosen}")
        return chosen

    # Fallback to Gemma 3 so testing can still run end-to-end.
    gemma3 = [name for name in supported if "gemma-3" in name.lower()]
    if gemma3:
        chosen = gemma3[0]
        print(f"Gemma 4 not available for this key/project. Falling back to: {chosen}")
        return chosen

    raise RuntimeError("No Gemma text-generation model found in list_models() output.")


def test_gemini_key(api_key: str, key_name: str, model_name: str) -> bool:
    """Test if a Gemini API key is valid by making a simple API call."""
    try:
        genai.configure(api_key=api_key)
        model = genai.GenerativeModel(model_name)

        # Simple test prompt
        response = model.generate_content("Say 'Hello' in one word.")

        if response and response.text:
            print(f"✅ {key_name}: WORKING ({model_name})")
            print(f"   Response: {response.text.strip()[:50]}...")
            return True
        else:
            print(f"❌ {key_name}: No response received ({model_name})")
            return False

    except Exception as e:
        print(f"❌ {key_name}: FAILED ({model_name})")
        print(f"   Error Type: {type(e).__name__}")
        print(f"   Error Message: {str(e)}")
        return False

# %%
# Get all Google API keys from environment
google_keys = {}

# Check for various key naming patterns
key_patterns = [
    "GOOGLE_API_KEY_1",
    "GOOGLE_API_KEY_2",
    "GOOGLE_API_KEY_3",
    "GOOGLE_API_KEY_4",
    "GOOGLE_API_KEY_5",
    "GOOGLE_API_KEY_6",
    "GOOGLE_API_KEY_7",
    "GOOGLE_API_KEY_8",
    "GOOGLE_API_KEY_9",
    "GOOGLE_API_KEY_10",
    "GOOGLE_API_KEY_11",
    "GOOGLE_API_KEY_12",
    "GOOGLE_API_KEY_13",
    "GOOGLE_API_KEY_14",
]

for key_name in key_patterns:
    value = os.getenv(key_name)
    if value:
        # Clean up the value (remove quotes if present)
        value = value.strip().strip("'\"")
        google_keys[key_name] = value

print(f"Found {len(google_keys)} API key(s):")
for key_name in google_keys:
    masked = google_keys[key_name][:10] + "..." + google_keys[key_name][-4:]
    print(f"  - {key_name}: {masked}")
# Out:
# Found 13 API key(s):
#   - GOOGLE_API_KEY_2: AIzaSyBuon...1sTo
#   - GOOGLE_API_KEY_3: AIzaSyCbO_...S_nQ
#   - GOOGLE_API_KEY_4: AIzaSyDQiQ...r_24
#   - GOOGLE_API_KEY_5: AIzaSyCDiy...RFG0
#   - GOOGLE_API_KEY_6: AIzaSyAwvK...Ka9A
#   - GOOGLE_API_KEY_7: AIzaSyDlb7...FW1A
#   - GOOGLE_API_KEY_8: AIzaSyDasG...DQ1Y
#   - GOOGLE_API_KEY_9: AIzaSyCBxq...ggE4
#   - GOOGLE_API_KEY_10: AIzaSyAWQo...9fR0
#   - GOOGLE_API_KEY_11: AIzaSyAvea...CQAo
#   - GOOGLE_API_KEY_12: AIzaSyCTMi...U5o8
#   - GOOGLE_API_KEY_13: AIzaSyA-YJ...c9b4
#   - GOOGLE_API_KEY_14: AIzaSyD97Y...EMqg

# %%
# Test all keys
print("=" * 60)
print("Testing API Keys")
print("=" * 60)
print()

# Resolve the correct model name from current API access (prefers Gemma 4).
test_model_name = resolve_test_model_name()
print()
working_keys = []
failed_keys = []

for key_name, api_key in google_keys.items():
    if test_gemini_key(api_key, key_name, test_model_name):
        working_keys.append(key_name)
    else:
        failed_keys.append(key_name)
    print()

# Summary
print("=" * 60)
print("SUMMARY")
print("=" * 60)
print(f"Model tested: {test_model_name}")
print(f"✅ Working keys: {len(working_keys)}")
for key in working_keys:
    print(f"   - {key}")
print(f"❌ Failed keys: {len(failed_keys)}")
for key in failed_keys:
    print(f"   - {key}")
# Out:
# ============================================================
# Testing API Keys
# ============================================================
#
# Using Gemma 4 model: gemma-4-26b-a4b-it
#
# ❌ GOOGLE_API_KEY_2: FAILED (gemini-2.5-flash)
#    Error Type: PermissionDenied
#    Error Message: 403 Your API key was reported as leaked. Please use another API key.
#
# ✅ GOOGLE_API_KEY_3: WORKING (gemini-2.5-flash)
#    Response: Hello....
#
# ✅ GOOGLE_API_KEY_4: WORKING (gemini-2.5-flash)
#    Response: Hello....
#
# ✅ GOOGLE_API_KEY_5: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_6: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_7: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_8: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_9: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_10: WORKING (gemini-2.5-flash)
#    Response: Hello....
#
# ✅ GOOGLE_API_KEY_11: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_12: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_13: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ✅ GOOGLE_API_KEY_14: WORKING (gemini-2.5-flash)
#    Response: Hello...
#
# ============================================================
# SUMMARY
# ============================================================
# Model tested: gemini-2.5-flash
# ✅ Working keys: 12
#    - GOOGLE_API_KEY_3
#    - GOOGLE_API_KEY_4
#    - GOOGLE_API_KEY_5
#    - GOOGLE_API_KEY_6
#    - GOOGLE_API_KEY_7
#    - GOOGLE_API_KEY_8
#    - GOOGLE_API_KEY_9
#    - GOOGLE_API_KEY_10
#    - GOOGLE_API_KEY_11
#    - GOOGLE_API_KEY_12
#    - GOOGLE_API_KEY_13
#    - GOOGLE_API_KEY_14
# ❌ Failed keys: 1
#    - GOOGLE_API_KEY_2

# %%
# Test every generateContent model with a real prompt and list only working ones
print("=" * 60)
print("TESTING ALL AVAILABLE MODELS (using first working key)")
print("=" * 60)

first_working_key = working_keys[2] if working_keys else None

if not first_working_key:
    print("No working keys found — cannot test models.")
else:
    genai.configure(api_key=google_keys[first_working_key])
    print(f"Using key: {first_working_key}\n")

    all_models = list(genai.list_models())
    text_model_ids = [
        m.name.replace("models/", "")
        for m in all_models
        if "generateContent" in (m.supported_generation_methods or [])
    ]

    print(f"Found {len(text_model_ids)} generateContent models. Testing each...\n")

    confirmed_working = []
    confirmed_failed = []

    for model_id in text_model_ids:
        try:
            m = genai.GenerativeModel(model_id)
            resp = m.generate_content("Reply with exactly one word: Hello")
            if resp and resp.text:
                print(f"  ✅ {model_id}")
                confirmed_working.append(model_id)
            else:
                print(f"  ❌ {model_id}  (empty response)")
                confirmed_failed.append(model_id)
        except Exception as e:
            short_err = str(e).split("\n")[0][:120]
            print(f"  ❌ {model_id}  → {short_err}")
            confirmed_failed.append(model_id)

    print()
    print("=" * 60)
    print(f"CONFIRMED WORKING MODELS ({len(confirmed_working)})")
    print("=" * 60)
    for mid in confirmed_working:
        print(f"  {mid}")

    print()
    print(f"Failed / unavailable: {len(confirmed_failed)}")
# Out:
# ============================================================
# TESTING ALL AVAILABLE MODELS (using first working key)
# ============================================================
# Using key: GOOGLE_API_KEY_6
#
# Found 33 generateContent models. Testing each...
#
#   ✅ gemini-2.5-flash
#   ❌ gemini-2.5-pro  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-2.0-flash  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-2.0-flash-001  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-2.0-flash-lite-001  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-2.0-flash-lite  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-2.5-flash-preview-tts  → 400 The requested combination of response modalities (TEXT) is not supported by the model. models/gemini-2.5-flash-previ
#   ❌ gemini-2.5-pro-preview-tts  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ✅ gemma-4-26b-a4b-it
#   ✅ gemma-4-31b-it
#   ✅ gemini-flash-latest
#   ✅ gemini-flash-lite-latest
#   ❌ gemini-pro-latest  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ✅ gemini-2.5-flash-lite
#   ❌ gemini-2.5-flash-image  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-3-pro-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ✅ gemini-3-flash-preview
#   ❌ gemini-3.1-pro-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-3.1-pro-preview-customtools  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ✅ gemini-3.1-flash-lite-preview
#   ✅ gemini-3.1-flash-lite
#   ❌ gemini-3-pro-image-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ nano-banana-pro-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-3.1-flash-image-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ lyria-3-clip-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ lyria-3-pro-preview  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ gemini-3.1-flash-tts-preview  → 400 Request contains an invalid argument.
#   ❌ gemini-robotics-er-1.5-preview  → 404 This model models/gemini-robotics-er-1.5-preview is no longer available. Please update your code to use a newer mode
#   ✅ gemini-robotics-er-1.6-preview
#   ❌ gemini-2.5-computer-use-preview-10-2025  → 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, hea
#   ❌ deep-research-max-preview-04-2026  → 400 This model only supports Interactions API.
#   ❌ deep-research-preview-04-2026  → 400 This model only supports Interactions API.
#   ❌ deep-research-pro-preview-12-2025  → 400 This model only supports Interactions API.
#
# ============================================================
# CONFIRMED WORKING MODELS (10)
# ============================================================
#   gemini-2.5-flash
#   gemma-4-26b-a4b-it
#   gemma-4-31b-it
#   gemini-flash-latest
#   gemini-flash-lite-latest
#   gemini-2.5-flash-lite
#   gemini-3-flash-preview
#   gemini-3.1-flash-lite-preview
#   gemini-3.1-flash-lite
#   gemini-robotics-er-1.6-preview
#
# Failed / unavailable: 23

# %%
from langsmith import Client
from typing import List, Dict, Any, Optional

# Initialize LangSmith client
langsmith_client = Client()

# Configuration
LANGSMITH_PROJECT = "aws"  # Replace with your project name
THREAD_ID = "anurag-light-english-thread-20251222-060515"  # Replace with actual thread ID

# Get thread history using metadata filter (official approach)
def get_thread_history(thread_id: str, project_name: str):
    """
    Gets a history of all runs in the thread using metadata filtering.
    """
    # Filter runs by the specific thread using metadata
    # This searches for runs where metadata contains session_id, conversation_id, or thread_id
    filter_string = f'and(in(metadata_key, ["session_id","conversation_id","thread_id"]), eq(metadata_value, "{thread_id}"))'
    
    print(f"Searching for thread: {thread_id}")
    print(f"Project: {project_name}")
    print(f"Filter: {filter_string}")
    print("=" * 60)
    
    try:
        # Get all runs matching the filter
        runs = list(langsmith_client.list_runs(
            project_name=project_name, 
            filter=filter_string
        ))
        
        print(f"Total runs found: {len(runs)}")
        print()
        
        # Sort by start time (most recent first)
        runs = sorted(runs, key=lambda run: run.start_time, reverse=True)
        
        # Display all runs
        for i, run in enumerate(runs, 1):
            print(f"Run #{i}")
            print(f"  Run ID: {run.id}")
            print(f"  Name: {run.name}")
            print(f"  Run Type: {run.run_type}")
            print(f"  Status: {run.status}")
            print(f"  Start Time: {run.start_time}")
            print(f"  End Time: {run.end_time}")
            print(f"  Metadata: {run.metadata}")
            if run.error:
                print(f"  Error: {run.error}")
            if run.inputs:
                print(f"  Inputs: {str(run.inputs)[:300]}...")
            if run.outputs:
                print(f"  Outputs: {str(run.outputs)[:300]}...")
            print("-" * 60)
        
        return runs
        
    except Exception as e:
        print(f"Error retrieving thread history: {e}")
        import traceback
        traceback.print_exc()
        return []

# Alternative: Get runs using session_name (for LangGraph-style threads)
def get_thread_by_session(thread_id: str, project_name: str):
    """
    Alternative approach using session_name parameter.
    """
    print(f"\nAlternative: Using session_name parameter")
    print(f"Thread ID: {thread_id}")
    print("=" * 60)
    
    try:
        runs = list(langsmith_client.list_runs(
            project_name=project_name,
            session_name=thread_id,
            limit=100
        ))
        
        print(f"Total runs found: {len(runs)}")
        print()
        
        for i, run in enumerate(runs, 1):
            print(f"Run #{i}: {run.name} | Type: {run.run_type} | Status: {run.status}")
        
        return runs
        
    except Exception as e:
        print(f"Error: {e}")
        return []

# Execute both approaches
print("APPROACH 1: Metadata Filter (Official Documentation)")
print("=" * 60)
runs_metadata = get_thread_history(THREAD_ID, LANGSMITH_PROJECT)

print("\n" + "=" * 60)
print("APPROACH 2: Session Name")
print("=" * 60)
runs_session = get_thread_by_session(THREAD_ID, LANGSMITH_PROJECT)

# List all sessions to find available threads
print("\n" + "=" * 60)
print("List all sessions (threads) in project:")
print("=" * 60)

try:
    sessions = list(langsmith_client.list_sessions(
        project_name=LANGSMITH_PROJECT,
        limit=20
    ))
    
    print(f"Found {len(sessions)} sessions:")
    for session in sessions:
        print(f"  Session: {session.name} | Run Count: {session.run_count}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# APPROACH 1: Metadata Filter (Official Documentation)
# ============================================================
# Searching for thread: anurag-light-english-thread-20251222-060515
# Project: aws
# Filter: and(in(metadata_key, ["session_id","conversation_id","thread_id"]), eq(metadata_value, "anurag-light-english-thread-20251222-060515"))
# ============================================================
# Total runs found: 0
#
#
# ============================================================
# APPROACH 2: Session Name
# ============================================================
#
# Alternative: Using session_name parameter
# Thread ID: anurag-light-english-thread-20251222-060515
# ============================================================
# Total runs found: 100
#
# Run #1: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #2: START | Type: chain | Status: success
# Run #3: LangGraph | Type: chain | Status: success
# Run #4: ChatGoogleGenerativeAI | Type: llm | Status: error
# Run #5: START | Type: chain | Status: error
# Run #6: LangGraph | Type: chain | Status: error
# Run #7: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #8: START | Type: chain | Status: success
# Run #9: LangGraph | Type: chain | Status: success
# Run #10: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #11: START | Type: chain | Status: success
# Run #12: LangGraph | Type: chain | Status: success
# Run #13: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #14: START | Type: chain | Status: success
# Run #15: LangGraph | Type: chain | Status: success
# Run #16: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #17: START | Type: chain | Status: success
# Run #18: LangGraph | Type: chain | Status: success
# Run #19: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #20: START | Type: chain | Status: success
# Run #21: LangGraph | Type: chain | Status: success
# Run #22: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #23: START | Type: chain | Status: success
# Run #24: LangGraph | Type: chain | Status: success
# Run #25: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #26: START | Type: chain | Status: success
# Run #27: LangGraph | Type: chain | Status: success
# Run #28: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #29: START | Type: chain | Status: success
# Run #30: LangGraph | Type: chain | Status: success
# Run #31: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #32: START | Type: chain | Status: success
# Run #33: LangGraph | Type: chain | Status: success
# Run #34: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #35: START | Type: chain | Status: success
# Run #36: LangGraph | Type: chain | Status: success
# Run #37: ChatGoogleGenerativeAI | Type: llm | Status: error
# Run #38: START | Type: chain | Status: error
# Run #39: LangGraph | Type: chain | Status: error
# Run #40: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #41: START | Type: chain | Status: success
# Run #42: LangGraph | Type: chain | Status: success
# Run #43: START | Type: chain | Status: success
# Run #44: LangGraph | Type: chain | Status: success
# Run #45: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #46: START | Type: chain | Status: success
# Run #47: LangGraph | Type: chain | Status: success
# Run #48: ChatGoogleGenerativeAI | Type: llm | Status: error
# Run #49: START | Type: chain | Status: error
# Run #50: LangGraph | Type: chain | Status: error
# Run #51: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #52: START | Type: chain | Status: success
# Run #53: LangGraph | Type: chain | Status: success
# Run #54: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #55: REVISION_START | Type: chain | Status: success
# Run #56: LangGraph | Type: chain | Status: success
# Run #57: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #58: REVISION_START | Type: chain | Status: success
# Run #59: LangGraph | Type: chain | Status: success
# Run #60: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #61: START | Type: chain | Status: success
# Run #62: LangGraph | Type: chain | Status: success
# Run #63: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #64: START | Type: chain | Status: success
# Run #65: LangGraph | Type: chain | Status: success
# Run #66: LangGraph | Type: chain | Status: error
# Run #67: ChatGoogleGenerativeAI | Type: llm | Status: error
# Run #68: QUESTION_PRESENTER | Type: chain | Status: error
# Run #69: LangGraph | Type: chain | Status: error
# Run #70: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #71: REVISION_START | Type: chain | Status: success
# Run #72: LangGraph | Type: chain | Status: success
# Run #73: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #74: REVISION_START | Type: chain | Status: success
# Run #75: LangGraph | Type: chain | Status: success
# Run #76: START | Type: chain | Status: success
# Run #77: LangGraph | Type: chain | Status: success
# Run #78: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #79: START | Type: chain | Status: success
# Run #80: LangGraph | Type: chain | Status: success
# Run #81: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #82: START | Type: chain | Status: success
# Run #83: LangGraph | Type: chain | Status: success
# Run #84: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #85: START | Type: chain | Status: success
# Run #86: LangGraph | Type: chain | Status: success
# Run #87: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #88: START | Type: chain | Status: success
# Run #89: LangGraph | Type: chain | Status: success
# Run #90: _route_with_manager_check | Type: chain | Status: success
# Run #91: _route_with_manager_check | Type: chain | Status: success
# Run #92: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #93: APK | Type: chain | Status: success
# Run #94: LangGraph | Type: chain | Status: success
# Run #95: ChatGoogleGenerativeAI | Type: llm | Status: success
# Run #96: APK | Type: chain | Status: success
# Run #97: LangGraph | Type: chain | Status: success
# Run #98: ChatGoogleGenerativeAI | Type: llm | Status: error
# Run #99: APK | Type: chain | Status: error
# Run #100: LangGraph | Type: chain | Status: error
#
# ============================================================
# List all sessions (threads) in project:
# ============================================================
# Error: 'Client' object has no attribute 'list_sessions'
