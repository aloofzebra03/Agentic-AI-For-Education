# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path=".env", override=True)
# Out:
# True

# %%
from transformers import pipeline
import os

pipe = pipeline("automatic-speech-recognition", model="vasista22/whisper-kannada-tiny",token = False)
# Out:
# Device set to use cpu

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="vasista22/whisper-kannada-tiny")
# Out:
# Device set to use cpu

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq
import os

processor = AutoProcessor.from_pretrained("vasista22/whisper-kannada-tiny",token = os.getenv("HF_API_TOKEN"))
model = AutoModelForSpeechSeq2Seq.from_pretrained("vasista22/whisper-kannada-tiny",token = os.getenv("HF_API_TOKEN"))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\micromamba\envs\langchain\Lib\site-packages\huggingface_hub\utils\_http.py:407, in hf_raise_for_status(response, endpoint_name)
#     406 try:
# --> 407     response.raise_for_status()
#     408 except HTTPError as e:
#
# File c:\micromamba\envs\langchain\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/vasista22/whisper-kannada-tiny/resolve/main/processor_config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
